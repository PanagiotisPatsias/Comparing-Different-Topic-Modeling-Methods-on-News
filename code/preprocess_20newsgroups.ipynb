# %%
from sklearn.datasets import fetch_20newsgroups
import pandas as pd

# Load the dataset
newsgroups_data = fetch_20newsgroups(subset='all')
texts = newsgroups_data.data  # List of texts
labels = newsgroups_data.target  # List of target labels
label_names = newsgroups_data.target_names  # Names of the categories
# Convert to a DataFrame for easier handling
df = pd.DataFrame({'text': texts, 'label': labels})
df['label_name'] = df['label'].apply(lambda x: label_names[x])

df[['label_name']].value_counts()
# Out:
# label_name
# rec.sport.hockey            999
# soc.religion.christian      997
# rec.motorcycles             996
# rec.sport.baseball          994
# sci.crypt                   991
# rec.autos                   990
# sci.med                     990
# comp.windows.x              988
# sci.space                   987
# comp.os.ms-windows.misc     985
# sci.electronics             984
# comp.sys.ibm.pc.hardware    982
# misc.forsale                975
# comp.graphics               973
# comp.sys.mac.hardware       963
# talk.politics.mideast       940
# talk.politics.guns          910
# alt.atheism                 799
# talk.politics.misc          775
# talk.religion.misc          628
# Name: count, dtype: int64

# %%
# Example manual grouping of the original 20 categories into 6 groups
label_groups = {
    'comp.graphics': 'Technology',
    'comp.os.ms-windows.misc': 'Technology',
    'comp.sys.ibm.pc.hardware': 'Technology',
    'comp.sys.mac.hardware': 'Technology',
    'comp.windows.x': 'Technology',

    'rec.autos': 'Vehicles',
    'rec.motorcycles': 'Vehicles',

    'rec.sport.baseball': 'Sport',
    'rec.sport.hockey': 'Sport',

    'sci.crypt': 'Science',
    'sci.electronics': 'Science',
    'sci.med': 'Science',
    'sci.space': 'Science',

    'talk.politics.guns': 'Politics',
    'talk.politics.mideast': 'Politics',
    'talk.politics.misc': 'Politics',
    'talk.religion.misc': 'Religion',

    'alt.atheism': 'Religion',
    'misc.forsale': 'Miscellaneous',
}

# Create a new column in the DataFrame for the broader group
df['group'] = df['label_name'].map(label_groups)

# Display the new DataFrame with broader groups
df[['group']].value_counts()
# Out:
# group
# Technology       4891
# Science          3952
# Politics         2625
# Sport            1993
# Vehicles         1986
# Religion         1427
# Miscellaneous     975
# Name: count, dtype: int64

# %%
df.columns = ['text','label20','labels_name20','label']
df
# Out:
#                                                     text  label20  \
# 0      From: Mamatha Devineni Ratnam <mr47+@andrew.cm...       10
# 1      From: mblawson@midway.ecn.uoknor.edu (Matthew ...        3
# 2      From: hilmi-er@dsv.su.se (Hilmi Eren)\nSubject...       17
# 3      From: guyd@austin.ibm.com (Guy Dawson)\nSubjec...        3
# 4      From: Alexander Samuel McDiarmid <am2o+@andrew...        4
# ...                                                  ...      ...
# 18841  From: jim.zisfein@factory.com (Jim Zisfein) \n...       13
# 18842  From: rdell@cbnewsf.cb.att.com (richard.b.dell...       12
# 18843  From: westes@netcom.com (Will Estes)\nSubject:...        3
# 18844  From: steve@hcrlgw (Steven Collins)\nSubject: ...        1
# 18845  From: chriss@netcom.com (Chris Silvester)\nSub...        7
#
#                   labels_name20       label
# 0              rec.sport.hockey       Sport
# 1      comp.sys.ibm.pc.hardware  Technology
# 2         talk.politics.mideast    Politics
# 3      comp.sys.ibm.pc.hardware  Technology
# 4         comp.sys.mac.hardware  Technology
# ...                         ...         ...
# 18841                   sci.med     Science
# 18842           sci.electronics     Science
# 18843  comp.sys.ibm.pc.hardware  Technology
# 18844             comp.graphics  Technology
# 18845                 rec.autos    Vehicles
#
# [18846 rows x 4 columns]

# %%
df.to_csv('fetch_7newsgroups.csv')
